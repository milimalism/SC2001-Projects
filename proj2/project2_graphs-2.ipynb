# %%
import pandas as pd
import matplotlib.pyplot as plt

array = pd.read_csv('outputA.csv')
heap = pd.read_csv('outputB.csv')

# %%
# Extract data from outputA.csv
edges = []
vertices = []
count = 1

best_ag = []
worst_ag = []
aver_ag = []

best_aa = []
worst_aa = []
aver_aa = []

best_ac = []
worst_ac = []
aver_ac = []

for _, row in array.iterrows():

    if count%3 == 1:
        best_ag.append(float(row['graph creating time']))
        best_aa.append(float(row['algorithm time']))
        best_ac.append(int(row['Number of algocomparisons']))

    elif count%3 == 2:
        worst_ag.append(float(row['graph creating time']))
        worst_aa.append(float(row['algorithm time']))
        worst_ac.append(int(row['Number of algocomparisons']))

    elif count%3 == 0:
        aver_ag.append(float(row['graph creating time']))
        aver_aa.append(float(row['algorithm time']))
        aver_ac.append(int(row['Number of algocomparisons']))
        edges.append(int(row['Number of edges']))
        vertices.append(int(row['Number of vertices']))
    
    count += 1

# %%
# Extract data from outputB.csv
count = 1

best_hg = []
worst_hg = []
aver_hg = []

best_ha = []
worst_ha = []
aver_ha = []

best_hc = []
worst_hc = []
aver_hc = []

for _, row in heap.iterrows():

    if count%3 == 1:
        best_hg.append(float(row['graph creating time']))
        best_ha.append(float(row['algorithm time']))
        best_hc.append(int(row['Number of algocomparisons']))

    elif count%3 == 2:
        worst_hg.append(float(row['graph creating time']))
        worst_ha.append(float(row['algorithm time']))
        worst_hc.append(int(row['Number of algocomparisons']))

    elif count%3 == 0:
        aver_hg.append(float(row['graph creating time']))
        aver_ha.append(float(row['algorithm time']))
        aver_hc.append(int(row['Number of algocomparisons']))
    
    count += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'graph creating time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Array - Graph creation
print(best_ag)
print(worst_ag)
print(aver_ag)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_ag, label = "Best")
plt.plot(edges, worst_ag, label = "Worst")
plt.plot(edges, aver_ag, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Graph Creating Time')
plt.title('Array: Graph Creation Time vs. Number of Vertices')
plt.show()

# %%
# Array - Algorithm time
print(best_aa)
print(worst_aa)
print(aver_aa)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_aa, label = "Best")
plt.plot(edges, worst_aa, label = "Worst")
plt.plot(edges, aver_aa, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Algorithm Time')
plt.title('Array: Algorithm Time vs. Number of Vertices')
plt.show()

# %%
# Array - Number of algocomparisons
print(best_ac)
print(worst_ac)
print(aver_ac)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_ac, label = "Best")
plt.plot(edges, worst_ac, label = "Worst")
plt.plot(edges, aver_ac, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Number of algocomparisons')
plt.title('Array: Number of algocomparisons vs. Number of Vertices')
plt.show()

# %%
# Heap - Graph creation
print(best_hg)
print(worst_hg)
print(aver_hg)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_hg, label = "Best")
plt.plot(edges, worst_hg, label = "Worst")
plt.plot(edges, aver_hg, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Graph Creation Time')
plt.title('Heap: Graph Creation Time vs. Number of Vertices')
plt.show()

# %%
# Heap - Algorithm time
print(best_ha)
print(worst_ha)
print(aver_ha)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_ha, label = "Best")
plt.plot(edges, worst_ha, label = "Worst")
plt.plot(edges, aver_ha, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Algorithm Time')
plt.title('Heap: Algorithm Time vs. Number of Vertices')
plt.show()

# %%
# Heap - Number of algocomparisons
print(best_hc)
print(worst_hc)
print(aver_hc)

# Creating the graph
plt.figure(figsize=(10, 6))
plt.plot(edges, best_hc, label = "Best")
plt.plot(edges, worst_hc, label = "Worst")
plt.plot(edges, aver_hc, label = "Average")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Number of algocomparisons')
plt.title('Heap: Number of algocomparisons vs. Number of Vertices')
plt.show()

# %%
# Graph creation comparison (edge)
plt.figure(figsize=(10, 6))
plt.plot(edges, aver_ag, label = "Matrix")
plt.plot(edges, aver_hg, label = "List")

plt.legend()
plt.xlabel('Number of Edges')
plt.ylabel('Graph Creation Time')
plt.title('Graph Creation Time: Matrix vs. List (Edges)')
plt.show()

# %%
# Graph creation comparison (vertex)
plt.figure(figsize=(10, 6))
plt.plot(vertices, aver_ag, label = "Matrix")
plt.plot(vertices, aver_hg, label = "List")

plt.legend()
plt.xlabel('Number of Edges')
plt.ylabel('Graph Creation Time')
plt.title('Graph Creation Time: Matrix vs. List (Edges)')
plt.show()

# %%
# Algorithm time (edge)
plt.figure(figsize=(10, 6))
plt.plot(edges, aver_aa, label = "Matrix")
plt.plot(edges, aver_ha, label = "List")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time: Matrix vs. List (Vertices)')
plt.show()

# %%
# Algorithm time (vertex)
plt.figure(figsize=(10, 6))
plt.plot(vertices, aver_aa, label = "Matrix")
plt.plot(vertices, aver_ha, label = "List")

plt.legend()
plt.xlabel('Number of Edges')
plt.ylabel('Algorithm Time')
plt.title('Algorithm Time: Matrix vs. List (Edges)')
plt.show()

# %%
# Number of algocomparisons (edge)
plt.figure(figsize=(10, 6))
plt.plot(edges, aver_ac, label = "Matrix")
plt.plot(edges, aver_hc, label = "List")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Number of algocomparisons')
plt.title('Number of algocomparisons: Matrix vs. List (Vertices)')
plt.show()

# %%
# Number of algocomparisons (vertex)
plt.figure(figsize=(10, 6))
plt.plot(vertices, aver_ac, label = "Matrix")
plt.plot(vertices, aver_hc, label = "List")

plt.legend()
plt.xlabel('Number of Vertices')
plt.ylabel('Number of algocomparisons')
plt.title('Number of algocomparisons: Matrix vs. List (Vertices)')
plt.show()
